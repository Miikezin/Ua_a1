# %% [markdown]
# <a href="https://colab.research.google.com/github/Miikezin/Ua_a1/blob/main/unidade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(type(x))
print(type(nome))
print(type(nota))
print(type(fez_inscrição))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome= input("digite seu nome:")
# Out:
# digite seu nome:Miike

# %%
#criando variaveis de tipos diferentes
x = 10
nome = "anderson"
nota = 8.75
fez_inscrição = True

# %%
print(f"olá {nome},bem vindo a disciplina de programação")
# Out:
# olá Miike,bem vindo a disciplina de programação

# %% [markdown]
# #unidade 1

# %%
Nota_1 = int(input("DIGITE A NOTA:"))
Nota_1 = int(input("DIGITE A NOTA:"))

Nota_2 = int(input("DIGITE A NOTA:"))

Nota_3 = int(input("DIGITE A NOTA:"))

Nota_4 = int(input("DIGITE A NOTA:"))
# Out:
# DIGITE A NOTA:8
# DIGITE A NOTA:5
# DIGITE A NOTA:6
# DIGITE A NOTA:4
# DIGITE A NOTA:6

# %%
print("helloworld")
# Out:
# helloworld

# %%
media = (Nota_1 + Nota_2 + Nota_3 + Nota_4) / 4
if media >= 6:
    situacao = "APROVADO, PARABÉNS"
else:
    situacao = "REPROVADO, TENTE NOVAMENTE"

# %%
U1_A2

# %%
##U1_A2

# %%
print(5>10)
# Out:
# False

# %%
print(5<10)
# Out:
# True

# %%
#aguardando informaçoes
idade = 1
e_maior_de_idade = (idade >= 18)
print(e_maior_de_idade)
# Out:
# False

# %%
print(True and True)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
idade = input("digite sua idade:")
idade = int(idade)
e_maior_de_idade = (idade >= 18)
print(e_maior_de_idade)
# Out:
# digite sua idade:15
# False

# %%
idade = input("digite sua idade:")
idade = int(idade)
if idade >= 18:
    print("maior de idade")
else:
    print("menor de idade")
# Out:
# digite sua idade:15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1252/1750481393.py in <cell line: 0>()
#       1 idade = input("digite sua idade:")
# ----> 2 if idade >= 18:
#       3     print("maior de idade")
#       4 else:
#       5     print("menor de idade")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
idade = int(input("digite sua idade:"))
if idade < 18:
  print("menor de idade")
elif idade >= 18 and idade <65:
  print("adulto")
else:
  print("idoso")
# Out:
# digite sua idade:65
# idoso

# %%
idade = int(input("digite sua idade:"))
if idade < 12:
  print("recomendamos o filme infantil")
elif idade >= 18 and idade <65:
  print("recomendamos o filme 2")
else:
  print("recomendamos o filme 3")

  quantidade_de_ingresso = 10
  if quantidade_de_ingresso

# %%
idade = int(input("digite sua idade:"))
if idade < 12:
  print("recomendamos o filme infantil")
elif idade >= 18 and idade <65:
  print("recomendamos o filme 2")
else:
  print("recomendamos o filme 3")

# %%
quantidade_de_ingresso = 10
if quantidade_de_ingresso > 0:
  print("ingressos disponiveis")
else:
  print("ingressos esgotados")
# Out:
# ingressos disponiveis

# %% [markdown]
# ##U1_A3

# %%
numeros = [1,2,3,4,5]
for numeros in numeros:
  print("camiseta {numeros}")
# Out:
# camiseta {numeros}
# camiseta {numeros}
# camiseta {numeros}
# camiseta {numeros}
# camiseta {numeros}

# %%
numero = int(input("digite um numero:(ou 0 para sair)"))

while numero !=0:
  if numero % 2 == 0:
    print("o numero é par")
  else:
    print("o numero é impar")

 numero = int(input("digite um numero:(ou 0 para sair)")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# o numero é par
# ...

# %%
for x in  range(5):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
filmes = ["1","2","3","4","5"]
print("bem vindo a classificação do filme")
print("você tem 5 filmes para classificar")
print("digite '0' a qualquer momento para parar")

for filme_item in filmes:
  classificação = input(f"como você classifica '{filme_item}' de 1 a 5(ou 0 para parar)")
  if classificação == '0':
    print("que pena")
    break

  classificação = int(classificação)
  if classificação < 1 or classificação > 5:
    print("classificação invalida")
  else:
    print(f"voce classificou '{filme_item}' com '{classificação}' estrelas")
# Out:
# bem vindo a classificação do filme
# você tem 5 filmes para classificar
# digite '0' a qualquer momento para parar
# como você classifica '1' de 1 a 5(ou 0 para parar)5
# voce classificou '1' com '5' estrelas
# como você classifica '2' de 1 a 5(ou 0 para parar)2
# voce classificou '2' com '2' estrelas
# como você classifica '3' de 1 a 5(ou 0 para parar)5
# voce classificou '3' com '5' estrelas
