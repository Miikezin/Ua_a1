# %% [markdown]
# <a href="https://colab.research.google.com/github/Miikezin/Ua_a1/blob/main/atividade_Fun%C3%A7%C3%B5es_Em_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SISTEMA DE GESTÃO DE NOTAS

# %%
def cadastrar_notas():
   quantidade = int(input("Quantas notas deseja inserir? "))

   for i in range(quantidade):
    nota = float(input(f"Digite a {i + 1}ª nota: "))
    notas.append(nota)

# %% [markdown]
# ## Função para calcular a média

# %%
def calcular_media():
  media = sum(notas) / len(notas)
  return media

# %% [markdown]
# # Função para verificar a situação do aluno

# %%
def verificar_situacao(media):
  if media >= 7:
    return "APROVADO"
  else:
    return "REPROVADO"

# %%
cadastrar_notas()
media = calcular_media()
situacao = verificar_situacao(media)
print("\n===== RELATÓRIO FINAL =====")
print("Notas inseridas:", notas)
print(f"Média: {media:.2f}")
print("Situação:", situacao)
# Out:
# Quantas notas deseja inserir? 10
# Digite a 1ª nota: 9
# Digite a 2ª nota: 7
# Digite a 3ª nota: 7
# Digite a 4ª nota: 5
# Digite a 5ª nota: 4
# Digite a 6ª nota: 5
# Digite a 7ª nota: 6
# Digite a 8ª nota: 9
# Digite a 9ª nota: 5
# Digite a 10ª nota: 8
#
# ===== RELATÓRIO FINAL =====
# Notas inseridas: [5.0, 6.0, 7.0, 8.0, 9.0, 7.0, 6.0, 7.0, 8.0, 9.0, 7.0, 7.0, 5.0, 4.0, 5.0, 6.0, 9.0, 5.0, 8.0]
# Média: 6.74
# Situação: REPROVADO
