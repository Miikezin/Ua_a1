# %% [markdown]
# <a href="https://colab.research.google.com/github/Miikezin/Ua_a1/blob/main/a2_U2_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


# ==========================================
# 1. CLASSE LIVRO
# ==========================================

class Livro:
    def __init__(self, titulo, autor, genero, quantidade_disponivel):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.quantidade_disponivel = quantidade_disponivel


# ==========================================
# 2. LISTA DE LIVROS
# ==========================================

livros = []


# ==========================================
# 3. CADASTRAR LIVRO
# ==========================================

def cadastrar_livro():
    print("\n--- CADASTRAR LIVRO ---")

    titulo = input("Digite o título: ")
    autor = input("Digite o autor: ")
    genero = input("Digite o gênero: ")
    quantidade = int(input("Digite a quantidade disponível: "))

    novo_livro = Livro(
        titulo,
        autor,
        genero,
        quantidade
    )

    livros.append(novo_livro)

    print("\nLivro cadastrado com sucesso!")


# ==========================================
# 4. LISTAR LIVROS
# ==========================================

def listar_livros():
    print("\n--- LISTA DE LIVROS ---")

    if len(livros) == 0:
        print("Nenhum livro cadastrado.")
        return

    for livro in livros:
        print(
            f"Título: {livro.titulo} | "
            f"Autor: {livro.autor} | "
            f"Gênero: {livro.genero} | "
            f"Quantidade: {livro.quantidade_disponivel}"
        )


# ==========================================
# 5. BUSCAR LIVRO
# ==========================================

def buscar_livro():
    print("\n--- BUSCAR LIVRO ---")

    titulo_busca = input("Digite o título do livro: ")

    for livro in livros:
        if livro.titulo.lower() == titulo_busca.lower():
            print("\nLivro encontrado!")
            print(f"Título: {livro.titulo}")
            print(f"Autor: {livro.autor}")
            print(f"Gênero: {livro.genero}")
            print(f"Quantidade: {livro.quantidade_disponivel}")
            return

    print("\nLivro não encontrado.")


# ==========================================
# 6. GERAR GRÁFICO
# ==========================================

def gerar_grafico():
    print("\n--- GRÁFICO DE LIVROS POR GÊNERO ---")

    if len(livros) == 0:
        print("Não há livros cadastrados.")
        return

    generos = {}

    for livro in livros:
        if livro.genero in generos:
            generos[livro.genero] += livro.quantidade_disponivel
        else:
            generos[livro.genero] = livro.quantidade_disponivel

    plt.bar(generos.keys(), generos.values())

    plt.title("Quantidade de livros por gênero")
    plt.xlabel("Gênero")
    plt.ylabel("Quantidade de livros")

    plt.show()


# ==========================================
# 7. MENU PRINCIPAL
# ==========================================

while True:

    print("\n================================")
    print("     SISTEMA DA BIBLIOTECA")
    print("================================")

    print("1 - Cadastrar livro")
    print("2 - Listar livros")
    print("3 - Buscar livro")
    print("4 - Gerar gráfico")
    print("5 - Sair")

    opcao = input("Digite uma opção: ")

    if opcao == "1":
        cadastrar_livro()

    elif opcao == "2":
        listar_livros()

    elif opcao == "3":
        buscar_livro()

    elif opcao == "4":
        gerar_grafico()

    elif opcao == "5":
        print("\nPrograma encerrado.")
        break

    else:
        print("\nOpção inválida. Digite um número de 1 a 5.")
# Out:
# ...
#      SISTEMA DA BIBLIOTECA
# ...
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Digite uma opção: 1
#
# --- CADASTRAR LIVRO ---
# Digite o título: o principe
# Digite o autor: maquiavel
# Digite o gênero: politica
# Digite a quantidade disponível: 5
#
# Livro cadastrado com sucesso!
#
# ...
#      SISTEMA DA BIBLIOTECA
# ...
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Digite uma opção: 1
#
# --- CADASTRAR LIVRO ---
# Digite o título: o vendedor de sonhos:o chamado
# Digite o autor: augusto cury
# Digite o gênero: historia
# Digite a quantidade disponível: 3
#
# Livro cadastrado com sucesso!
#
# ...
#      SISTEMA DA BIBLIOTECA
# ...
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# 4 - Gerar gráfico
# 5 - Sair
# Digite uma opção: da alma e dos ossos
#
# Opção inválida. Digite um número de 1 a 5.
#
# ...
#      SISTEMA DA BIBLIOTECA
# ...
# 1 - Cadastrar livro
# 2 - Listar livros
# 3 - Buscar livro
# ...
